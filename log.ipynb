# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(r"C:\Users\prakh\Downloads\titanic (1)\train.csv")
data = {
    "Survived" : df["Survived"].tolist(),
    "Pclass" : df["Pclass"].tolist(),
    "Name" : df["Name"].tolist(),
    "Sex" : df["Sex"].tolist(),
    "Age" : df["Age"].tolist(),
    "SibSp" : df["SibSp"].tolist(),
    "Parch" : df["Parch"].tolist(),
    "Ticket" : df["Ticket"].tolist(),
    "Fare" : df["Fare"].tolist(),
    "Cabin" : df["Cabin"].tolist(),
    "Embarked" : df["Embarked"].tolist()    
}
old_data = data.copy()

# %%
percentules = np.percentile(data["Fare"], [33, 66, 99])
print(percentules)
# Out:
# [  8.61295  26.      249.00622]

# %% [markdown]
# Visualizing each column with survived column
# Median fare = 15

# %%
for key in data:
    if key == "Name":
        continue 
    if key == "Fare":
        survived_percentages = [0,0,0]
        x_vals = data[key]
        y_vals = data["Survived"]
        y = [0,0,0]
        for i in range(len(x_vals)):

            if x_vals[i] <= 9:
                y[0] += 1
            elif x_vals[i] > 9 and x_vals[i] <= 26:
                y[1] += 1
            else:
                y[2] += 1
                
        count = [0,0,0]
        for i in range(len(x_vals)):
            if y_vals[i] == 1 and x_vals[i] <= 9:
                count[0] += 1
            if y_vals[i] == 1 and x_vals[i] > 9 and x_vals[i] <= 26:
                count[1] += 1
            if y_vals[i] == 1 and x_vals[i] > 26 :
                count[2] += 1
            
        for i in range(len(y)):
            survived_percentages[i] = (count[i] / y[i]) * 100
        
        x_labels = ["Less than 9", "Between 9 and 26", "Above 26"]
        plt.figure(figsize=(10, 6))
        plt.bar(x_labels, count)
        plt.xlabel(key)
        plt.ylabel('Count')
        for i, percent in enumerate(survived_percentages):
            plt.text(i, count[i] + 1, f'{percent:.1f}%', ha='center')
        
        denominator = 0
        for i in survived_percentages:
            denominator += i
        for i in range(len(survived_percentages)):
            reduced_percentages.append(survived_percentages[i] / denominator )
        unique_vals = list(set(x_vals))
        for i in range(len(x_vals)):
        
            if x_vals[i] <= 9:
                x_vals[i] = reduced_percentages[0]
            elif x_vals[i] > 9 and x_vals[i] <= 26:
                x_vals[i] = reduced_percentages[1]
            else:
                x_vals[i] = reduced_percentages[2]
        continue
    if key == "Age":
        survived_percentages = [0,0,0]
        x_vals = data[key]
        y_vals = data["Survived"]
        y = [0,0,0]
        for i in range(len(x_vals)):

            if x_vals[i] <= 18:
                y[0] += 1
            elif x_vals[i] > 18 and x_vals[i] <= 45:
                y[1] += 1
            else:
                y[2] += 1
                
        count = [0,0,0]
        for i in range(len(x_vals)):
            if y_vals[i] == 1 and x_vals[i] <= 18:
                count[0] += 1
            if y_vals[i] == 1 and x_vals[i] > 18 and x_vals[i] <= 45:
                count[1] += 1
            if y_vals[i] == 1 and x_vals[i] > 45 :
                count[2] += 1
            
        for i in range(len(y)):
            survived_percentages[i] = (count[i] / y[i]) * 100
        
        x_labels = ["Less than 18", "Between 18 and 45", "Above 45"]
        plt.figure(figsize=(10, 6))
        plt.bar(x_labels, count)
        plt.xlabel(key)
        plt.ylabel('Count')
        for i, percent in enumerate(survived_percentages):
            plt.text(i, count[i] + 1, f'{percent:.1f}%', ha='center')
        
        denominator = 0
        for i in survived_percentages:
            denominator += i
        for i in range(len(survived_percentages)):
            reduced_percentages.append(survived_percentages[i] / denominator )
        unique_vals = list(set(x_vals))
        for i in range(len(x_vals)):
        
            if x_vals[i] <= 18:
                x_vals[i] = reduced_percentages[0]
            elif x_vals[i] > 18 and x_vals[i] <= 45:
                x_vals[i] = reduced_percentages[1]
            else:
                x_vals[i] = reduced_percentages[2]
        continue
    if key == "Survived":
        continue
    if key == "Ticket":
        continue
    if key == "Cabin":
        continue
    if key == "Fare":
        survived_percentages = [0,0]
        x_vals = data[key]
        y_vals = data["Survived"]
        y = [0,0]
        for i in range(len(x_vals)):

            if x_vals[i] <= 15:
                y[0] += 1
            else:
                y[1] += 1
        count = [0,0]
        for i in range(len(x_vals)):
            if y_vals[i] == 1 and x_vals[i] <= 15:
                count[0] += 1
            if y_vals[i] == 1 and x_vals[i] > 15:
                count[1] += 1
        for i in range(len(y)):
            survived_percentages[i] = (count[i] / y[i]) * 100
        
        x_labels = ["Less than 15", "More than 15"]
        plt.figure(figsize=(10, 6))
        plt.bar(x_labels, count)
        plt.xlabel(key)
        plt.ylabel('Count')
        for i, percent in enumerate(survived_percentages):
            plt.text(i, count[i] + 1, f'{percent:.1f}%', ha='center')
            

        continue
    x_vals = data[key]
    # x = x_vals.copy()
    y_vals2 = data["Survived"]
    yvals1 = []
    for i in list(set(x_vals)):
        yvals1.append(x_vals.count(i))
    counts = []
    for val in list(set(x_vals)) :
        # Get indices where x_vals == val
        indices = [i for i, x in enumerate(x_vals) if x == val]
        
        # Count how many times val occurs
        count = len(indices)
        counts.append(count)
    survived_percentages = []

    for i in range(len(counts)):
        count = 0
        indices = [i for i, x in enumerate(y_vals2) if x == 1]
        for j in indices :
            if x_vals[j] == list(set(x_vals))[i]:
                count += 1
        if counts[i] == 0 :
            survived_percentages.append(0)
        else:
            survived_percentages.append((count/counts[i]) * 100)
        
    x_labels = [str(val) for val in  list(set(x_vals))]

    plt.figure(figsize=(10, 6))
    plt.bar(x_labels, counts)
    plt.xlabel(key)
    plt.ylabel('Count')
    for i, percent in enumerate(survived_percentages):
        plt.text(i, counts[i] + 1, f'{percent:.1f}%', ha='center')
    reduced_percentages = []
    denominator = 0
    for i in survived_percentages:
        denominator += i
    for i in range(len(survived_percentages)):
        reduced_percentages.append(survived_percentages[i] / denominator )
    unique_vals = list(set(x_vals))
    for i in range(len(x_vals)):
        for j in range(len(unique_vals)):
            if x_vals[i] == unique_vals[j]:
                # print(i,j)
                # print(j)
                x_vals[i] = reduced_percentages[j]

# %%
# def scaler(column):
    
#     pclass_array = np.array(data[column]).reshape(-1, 1)

#     scaler = MinMaxScaler(feature_range=(0, 1))
#     scaled_data = scaler.fit_transform(pclass_array)
#     scaled_pclass = scaled_data.flatten().tolist()

#     data[column] = scaled_pclass

# %%
del data["Name"]
del data["Ticket"]
del data["Cabin"]

# %% [markdown]
# NOW DOING LOGISTIC REGRESSION

# %%
df = pd.DataFrame(data)
X = df.drop("Survived", axis=1)
y = df["Survived"]

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 model = LogisticRegression()
# ----> 4 model.fit(X, y)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:1222, in LogisticRegression.fit(self, X, y, sample_weight)
#    1219 else:
#    1220     _dtype = [np.float64, np.float32]
# -> 1222 X, y = validate_data(
# ...
